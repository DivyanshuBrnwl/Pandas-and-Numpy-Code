# %%
d1 = {
    'Key1':[1, 2, 3, 4, 5, 'Divya'],
    'Key2':[7, 8, 9, True, 11, 12],
    'Key3':[13, 14, 15, 16, 17, 18], 
    'Key4':[19, 20, 21, 22, 23, 24]
}

# %%
import pandas as pd

# %%
pd.DataFrame(d1)
# Out:
#     Key1  Key2  Key3   Key4
# 0      1     7    13  False
# 1      2     8    14     20
# 2      3     9    15     21
# 3      4  True    16     22
# 4      5    11    17     23
# 5  Divya    12    18     24

# %%
df1 = pd.DataFrame(d1)

# %%
d2 = {
    'Key1':[1, 2, 3, 4, 5, 'Divya'],
    'Key2':[7, 8, 'kumar', True, 11, 12],
    'Key3':[13, 14, 15, 16, 17, 18], 
    'Key4':[False, 20, 21, 'iNeuron', 'pwSkills', 24]
}

# %%
df2 = pd.DataFrame(d2)

# %%
merge1 = pd.merge(df1, df2)

# %%
df1
# Out:
#     Key1  Key2  Key3   Key4
# a      1     7    13  False
# b      2     8    14     20
# c      3     9    15     21
# d      4  True    16     22
# e      5    11    17     23
# f  Divya    12    18     24

# %%
df2
# Out:
#     Key1   Key2  Key3      Key4
# 0      1      7    13     False
# 1      2      8    14        20
# 2      3  kumar    15        21
# 3      4   True    16   iNeuron
# 4      5     11    17  pwSkills
# 5  Divya     12    18        24

# %%
pd.merge(df1, df2, how = 'left', on = 'Key4')
# Out:
#   Key1_x Key2_x  Key3_x   Key4 Key1_y Key2_y  Key3_y
# 0      1      7      13  False      1      7    13.0
# 1      2      8      14     20      2      8    14.0
# 2      3      9      15     21      3  kumar    15.0
# 3      4   True      16     22    NaN    NaN     NaN
# 4      5     11      17     23    NaN    NaN     NaN
# 5  Divya     12      18     24  Divya     12    18.0

# %%
d11 = {
    'a':[1, 2, 3, 4, 5, 'Divya'],
    'b':[7, 8, 9, True, 11, 12],
    'c':[13, 14, 15, 16, 17, 18], 
    'd':[False, 20, 21, 22, 23, 24]
}

# %%
df11 = pd.DataFrame(d11)

# %%
d12 = {
    'Key1':[1, 2, 3, 4, 5, 'Divya'],
    'Key2':[7, 8, 'kumar', True, 11, 12],
    'Key3':[13, 14, 15, 16, 17, 18], 
    'Key4':[False, 20, 21, 'iNeuron', 'pwSkills', 24]
}

# %%
df12 = pd.DataFrame(d12)

# %%
pd.merge(df11, df12, how = 'left', left_on = 'a', right_on='Key1')
# Out:
#        a     b   c      d   Key1   Key2  Key3      Key4
# 0      1     7  13  False      1      7    13     False
# 1      2     8  14     20      2      8    14        20
# 2      3     9  15     21      3  kumar    15        21
# 3      4  True  16     22      4   True    16   iNeuron
# 4      5    11  17     23      5     11    17  pwSkills
# 5  Divya    12  18     24  Divya     12    18        24

# %%
type(d11)
# Out:
# dict

# %%
type(d12)
# Out:
# dict

# %%
df11.join(df12)
# Out:
#        a     b   c      d   Key1   Key2  Key3      Key4
# 0      1     7  13  False      1      7    13     False
# 1      2     8  14     20      2      8    14        20
# 2      3     9  15     21      3  kumar    15        21
# 3      4  True  16     22      4   True    16   iNeuron
# 4      5    11  17     23      5     11    17  pwSkills
# 5  Divya    12  18     24  Divya     12    18        24

# %%
d10 = {
    'Key11':[1, 2, 3, 4, 5, 'Divya'],
    'Key21':[7, 8, 9, True, 11, 12],
    'Key31':[13, 14, 15, 16, 17, 18], 
    'Key41':[19, 20, 21, 22, 23, 24]
}

# %%
d20 = {
    'Key1':[1, 2, 3, 4, 5, 'Divya'],
    'Key2':[7, 8, 'kumar', True, 11, 12],
    'Key3':[13, 14, 15, 16, 17, 18], 
    'Key4':[False, 20, 21, 'iNeuron', 'pwSkills', 24]
}

# %%
df10 = pd.DataFrame(d10)

# %%
df20 = pd.DataFrame(d20)

# %%
df10.join(df20, how = 'inner')
# Out:
#    Key11 Key21  Key31  Key41   Key1   Key2  Key3      Key4
# 0      1     7     13     19      1      7    13     False
# 1      2     8     14     20      2      8    14        20
# 2      3     9     15     21      3  kumar    15        21
# 3      4  True     16     22      4   True    16   iNeuron
# 4      5    11     17     23      5     11    17  pwSkills
# 5  Divya    12     18     24  Divya     12    18        24

# %%
pd.concat([df10, df20], axis = 0)
# Out:
#    Key11 Key21  Key31  Key41   Key1   Key2  Key3      Key4
# 0      1     7   13.0   19.0    NaN    NaN   NaN       NaN
# 1      2     8   14.0   20.0    NaN    NaN   NaN       NaN
# 2      3     9   15.0   21.0    NaN    NaN   NaN       NaN
# 3      4  True   16.0   22.0    NaN    NaN   NaN       NaN
# 4      5    11   17.0   23.0    NaN    NaN   NaN       NaN
# 5  Divya    12   18.0   24.0    NaN    NaN   NaN       NaN
# 0    NaN   NaN    NaN    NaN      1      7  13.0     False
# 1    NaN   NaN    NaN    NaN      2      8  14.0        20
# 2    NaN   NaN    NaN    NaN      3  kumar  15.0        21
# 3    NaN   NaN    NaN    NaN      4   True  16.0   iNeuron
# 4    NaN   NaN    NaN    NaN      5     11  17.0  pwSkills
# 5    NaN   NaN    NaN    NaN  Divya     12  18.0        24

# %%
pd.concat([df1, df2], axis = 0)
# Out:
#     Key1   Key2  Key3      Key4
# 0      1      7    13     False
# 1      2      8    14        20
# 2      3      9    15        21
# 3      4   True    16        22
# 4      5     11    17        23
# 5  Divya     12    18        24
# 0      1      7    13     False
# 1      2      8    14        20
# 2      3  kumar    15        21
# 3      4   True    16   iNeuron
# 4      5     11    17  pwSkills
# 5  Divya     12    18        24
